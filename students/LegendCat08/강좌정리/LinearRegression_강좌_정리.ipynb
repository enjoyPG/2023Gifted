# %% [markdown]
# <a href="https://colab.research.google.com/github/enjoyPG/2023Gifted/blob/main/students/LegendCat08/%EA%B0%95%EC%A2%8C%EC%A0%95%EB%A6%AC/LinearRegression_%EA%B0%95%EC%A2%8C_%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LinearRegression(선형회귀)
# ## Hypothesis (가설)
# $ H(x) = Wx + b $
#
# ##Cost Function
#
# ####가설에서 실제 값을 뺀 값
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Hypothesis 간략화
# $ H(x)=Wx $
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### W=2, cost(w)= 4.67
#
#
# ## LinearRegression의 cost 최소화 알고리즘
# #### *경사 하강 알고리즘(Gradient descent algorithm)*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [1] 아무 점이나 잡고 시작한다.
#
# [2]W값을 조금 줄인다 => cost(W,b)의 값이 줄어든다.
#
# [3]이때의 경사를 다시 찾아서 [2],[3]을 반복한다.
#
# [4]최솟값이 나온다.
#
# ↳ 이때 경사를 어떻게 찾느냐, => 미분!
#
# ![image.png](data:image/png;base64,...)
#
# 을 미분한다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# α는 상수(learning rate / 학습률)
#
# ":=" [업데이트하다 라는 뜻을 지님]
#
# cost를 미분한 값을 빼는 이유 = W의 절댓값이 작은 쪽으로 이동하기 위해서
#
# ##미분 과정
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##미분한 식을 계속 반복하면 W의 값이 계속 변하면서 cost의 최솟값을 찾을 수 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##경사 하강 알고리즘을 실행 할 때
# cost와 hypothesis가 위처럼 그려지는지 확인 하고 실행
